# %%
##CS595 ASSIGNMENT-3
##Decision Tree
import pandas as pd
import numpy as np
import csv
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import train_test_split
from sklearn import tree
from sklearn import metrics
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import  cross_val_score
from sklearn.preprocessing import Imputer

# %%
##For the FBI to develop predictive models for crime, to help the Bureau and police departments around the country to use machine learning 
##to better focus their resources on locations where crimes are more likely to be committed.
##We are expected to implement solution.

# %%
data=pd.read_csv("C:\\Users\\Dell\\Desktop\\CS595_IML\\communities.csv")

# %%
data
# Out:
#       state        communityname  fold  population  householdsize  \
# 0         1        Alabastercity     7        0.01           0.61
# 1         1    AlexanderCitycity    10        0.01           0.41
# 2         1         Annistoncity     3        0.03           0.34
# 3         1           Athenscity     8        0.01           0.38
# 4         1           Auburncity     1        0.04           0.37
# 5         1         Bessemercity     6        0.04           0.44
# 6         1       Birminghamcity     2        0.41           0.37
# 7         1          Cullmancity     1        0.01           0.30
# 8         1           Daphnecity     7        0.00           0.39
# 9         1          Decaturcity    10        0.06           0.39
# 10        1           Dothancity     4        0.07           0.41
# 11        1       Enterprisecity     2        0.02           0.43
# 12        1          Eufaulacity     5        0.01           0.46
# ...

# %%
data.describe()
# Out:
#              state         fold   population  householdsize  racepctblack  \
# count  1993.000000  1993.000000  1993.000000    1993.000000   1993.000000
# mean     28.683894     5.496237     0.057612       0.463437      0.179227
# std      16.401661     2.872650     0.126935       0.163747      0.252870
# min       1.000000     1.000000     0.000000       0.000000      0.000000
# 25%      12.000000     3.000000     0.010000       0.350000      0.020000
# 50%      34.000000     5.000000     0.020000       0.440000      0.060000
# 75%      42.000000     8.000000     0.050000       0.540000      0.230000
# max      56.000000    10.000000     1.000000       1.000000      1.000000
#
#        racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  \
# count   1993.000000   1993.000000  1993.000000  1993.000000  1993.000000
# mean       0.753984      0.153753     0.144089     0.424210     0.493914
# std        0.243807      0.208905     0.232531     0.155234     0.143584
# ...

# %%
data
# Out:
#       state        communityname  fold  population  householdsize  \
# 0         1        Alabastercity     7        0.01           0.61
# 1         1    AlexanderCitycity    10        0.01           0.41
# 2         1         Annistoncity     3        0.03           0.34
# 3         1           Athenscity     8        0.01           0.38
# 4         1           Auburncity     1        0.04           0.37
# 5         1         Bessemercity     6        0.04           0.44
# 6         1       Birminghamcity     2        0.41           0.37
# 7         1          Cullmancity     1        0.01           0.30
# 8         1           Daphnecity     7        0.00           0.39
# 9         1          Decaturcity    10        0.06           0.39
# 10        1           Dothancity     4        0.07           0.41
# 11        1       Enterprisecity     2        0.02           0.43
# 12        1          Eufaulacity     5        0.01           0.46
# ...

# %%
data
# Out:
#       state        communityname  fold  population  householdsize  \
# 0         1        Alabastercity     7        0.01           0.61
# 1         1    AlexanderCitycity    10        0.01           0.41
# 2         1         Annistoncity     3        0.03           0.34
# 3         1           Athenscity     8        0.01           0.38
# 4         1           Auburncity     1        0.04           0.37
# 5         1         Bessemercity     6        0.04           0.44
# 6         1       Birminghamcity     2        0.41           0.37
# 7         1          Cullmancity     1        0.01           0.30
# 8         1           Daphnecity     7        0.00           0.39
# 9         1          Decaturcity    10        0.06           0.39
# 10        1           Dothancity     4        0.07           0.41
# 11        1       Enterprisecity     2        0.02           0.43
# 12        1          Eufaulacity     5        0.01           0.46
# ...

# %%
def decisionTree():
    return tree.DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best')

# %%
def extractData(filename,communities,addstate = False,addcommunity = False):
    features = []
    xPositive=[]
    yPositive=[]
    xNegative=[]
    yNegative =[]
    with open(filename, 'r') as csvfile:
        filereader = csv.reader(csvfile)
        j = 0
        for i in filereader:
            if j > 0:
                data = i[3:len(i)-1]
                if addstate:
                    state = [0.0]*56
                    state[int(i[0])-1] = 1.0
                    data = data + state
                    features = features + ["state"+str(i) for i in range(56)]
                if addcommunity:
                    tmp = [0.0]*len(communities)
                    tmp[communities.index(i[1])] = 1.0
                    data = data + tmp
                    features = features + communities
                vect = np.array(data)
                #vect = np.array(i[3:len(i)-1])
                #x.append(vect.astype(np.float))
                if float(i[-1]) > 0.1:
                    xPositive.append(vect.astype(np.float))
                    yPositive.append(1)
                else:
                    xNegative.append(vect.astype(np.float))
                    yNegative.append(0)
            else:
                features = i[3:len(i)-1]
            j+=1
        """yPositive = np.array(yPositive)
        xPositive = np.array(xPositive)
        yNegative = np.array(yNegative)
        xNegative = np.array(xNegative)"""
        features = np.array(features)
        indxP = int(len(xPositive)*.6)
        indxN = int(len(xNegative)*.6)
        xTrain = xPositive[:indxP] + xNegative[:indxN]
        yTrain = yPositive[:indxP] + yNegative[:indxN]
        xTest = xPositive[indxP:] + xNegative[indxN:]
        yTest = yPositive[indxP:] + yNegative[indxN:]
        
        
            
            
        return xTrain,yTrain,xTest,yTest,features

# %%
#X, y = data.iloc[:,:-1], data.iloc[:, -1]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=1)

# %%
#from sklearn.cross_validation import train_test_split
#X, y = data.iloc[:,:-1], data.iloc[:, -1]
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.66, random_state=1)

# %%
def findCommunities():
    communities = []
    with open('C:\\Users\\Dell\\Desktop\\CS595_IML\\communities.csv', 'r') as csvfile:
        filereader = csv.reader(csvfile)
        j = 0
        for i in filereader:
            if j > 0:
                if i[1] not in communities:
                    communities.append(i[1])
            j+=1
    return communities

# %%
distintCommunities = findCommunities()
filename = 'C:\\Users\\Dell\\Desktop\\CS595_IML\\communities.csv'
x_Train,y_Train,x_Test,y_Test,features= extractData(filename,distintCommunities,addstate = False,addcommunity = False)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = DecisionTreeClassifier(random_state=0)

# %%
data['highcrime'] = data['ViolentCrimesPerPop'].map(lambda x: True if x > 0.1 else False)

# %%
mylist=data['highcrime'].value_counts()
true_percent = (mylist[1]/(data['highcrime'].shape))*100
false_percent =(mylist[0]/(data['highcrime'].shape))*100
print("true percetage is %2f " %true_percent)
print("false percentage is %2f "%false_percent)
# Out:
# true percetage is 62.719518
# false percentage is 37.280482

# %%
d1= data.copy()
del d1['state']
del d1['communityname']
del d1['fold']
del d1['highcrime']
del d1['ViolentCrimesPerPop']

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
##Decision tree depth analysis

# %%
dt_m1=decisionTree()
dt_m1.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
dt_m1=decisionTree()
dt_m1.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
dt_m2=decisionTree()
dt_m2.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
dt_m3=decisionTree()
dt_m3.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
dt_m4=decisionTree()
dt_m4.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
dt_m5=decisionTree()
dt_m5.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
dt_m6=decisionTree()
dt_m6.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=6,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=100, splitter='best')
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=6,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=100, splitter='best')

# %%
clf = tree.DecisionTreeClassifier()
from sklearn.metrics import precision_recall_fscore_support
without_split_clf = clf.fit(d1,data['highcrime'])
prediction = without_split_clf.predict(d1)
print("Accuracy: %2f" %clf.score(d1,data['highcrime']))
print(precision_recall_fscore_support(data['highcrime'],prediction))
# Out:
# Accuracy: 1.000000
# (array([ 1.,  1.]), array([ 1.,  1.]), array([ 1.,  1.]), array([ 743, 1250], dtype=int64))

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file=data) 
graph = graphviz.Source(dot_data) 
graph.render("data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-89f2c5b620cb> in <module>()
#       1 import graphviz
# ----> 2 dot_data = tree.export_graphviz(clf, out_file=data)
#       3 graph = graphviz.Source(dot_data)
#       4 graph.render("data")
#
# C:\Users\ar1\Anaconda3\lib\site-packages\sklearn\tree\export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters)
#     381     return_string = False
#     382     try:
# --> 383         if out_file == SENTINEL:
#     384             warnings.warn("out_file can be set to None starting from 0.18. "
#     385                           "This will be the default in 0.20.",
#
# C:\Users\ar1\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
# ...

# %%
##Analysis
##The accuracy is 1.000 same  in all depths ,even if I apply several preprocessing methods.
##The tree doesn't make sense as the accuracy is 1.00.
##The performance of both train and test were not fine as there is no change in the depth of the tree.
